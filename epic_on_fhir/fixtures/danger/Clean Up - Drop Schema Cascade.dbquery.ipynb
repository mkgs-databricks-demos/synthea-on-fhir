-- %%
DECLARE OR REPLACE VARIABLE schema_to_drop STRING DEFAULT 'mkgs_dev.dev_matthew_giglia_epic_on_fhir';
SET VARIABLE schema_to_drop = 'mkgs_dev.dev_matthew_giglia_epic_on_fhir';

DROP SCHEMA IF EXISTS IDENTIFIER(schema_to_drop) CASCADE;
